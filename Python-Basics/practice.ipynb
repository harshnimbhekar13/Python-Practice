# %% [markdown]
# # String

# %%
text = input("Enter a string: ")
print("Reversed String:", text[::-1])
# Out:
# Enter a string:  45
# Reversed String: 54

# %%
# !git add .
# !git commit -m "Day 16 Python Practice"
# !git push
# Out:
# warning: in the working copy of 'Python-Basics/if-else_statement.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Python-Basics/practice.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 32c3a06] Day 4 Python Practice
#  2 files changed, 160 insertions(+), 1 deletion(-)
#  create mode 100644 Python-Basics/practice.ipynb
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    b124211..32c3a06  main -> main

# %%
a = float(input("Enter Your CGPA : "))
print("Your CGPA is :- ",a)

if(a>5.0):
  print("Your are Selected")
else:
  print("Sorry...., Your are not selected")
# Out:
# Enter Your CGPA :  6.49
# Your CGPA is :-  6.49
# Your are Selected

# %%
# !git add .
# !git commit -m "Day 17 Python Practice"
# !git push
# Out:
# warning: in the working copy of 'Python-Basics/practice.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 2f364c2] Day 17 Python Practice
#  1 file changed, 26 insertions(+), 1 deletion(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    bdd7eeb..2f364c2  main -> main

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = int(input("Choose operation: "))

if choice == 1:
    print("Answer:", num1 + num2)

elif choice == 2:
    print("Answer:", num1 - num2)

elif choice == 3:
    print("Answer:", num1 * num2)

elif choice == 4:
    if num2 != 0:
        print("Answer:", num1 / num2)
    else:
        print("Cannot divide by zero")

else:
    print("Invalid choice")
# Out:
# Enter first number:  45
# Enter second number:  45
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Choose operation:  1
# Answer: 90.0

# %%
# !git add .
# !git commit -m "Day 18 Python Practice"
# !git push
# Out:
# warning: in the working copy of 'Python-Basics/practice.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main a46702f] Day 18 Python Practice
#  1 file changed, 52 insertions(+), 9 deletions(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    2f364c2..a46702f  main -> main

# %% [markdown]
# # if....,else

# %%
marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter your marks:  45
# Fail
