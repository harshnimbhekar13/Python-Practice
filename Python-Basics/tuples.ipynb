# %%
# Tuple

# %%
# It is a container data type , contain multiple value 
# It denotes by ()
# It Contains homogeneous

# %%
a=() #empty tuple

# %%
type(a)
# Out:
# tuple

# %%
x=(11) # Do not create single value tuple

# %%
type(x)
# Out:
# int

# %%
y=(12, )

# %%
type(y)
# Out:
# tuple

# %%
tup1=(22,55,78,98) # It is homogeneous tuple

# %%
tup2=('Harsh',True,22,11) # It is a hetrogeneous tuple

# %%
x=13,44

# %%
type(x)
# Out:
# tuple

# %%
# Concentation of tuple

# %%
(1,2,3)+(4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
(13,3,4)+(1,8,4)
# Out:
# (13, 3, 4, 1, 8, 4)

# %%
# Repetation of tuple

# %%
a=(33,11,88,44,99,22)

# %%
a[0]
# Out:
# 33

# %%
a[-1]
# Out:
# 22

# %%
# Slicing of Tuple

# %%
a[::-1]
# Out:
# (22, 99, 44, 88, 11, 33)

# %%
# Iteration of tuple

# %%
for i in a:
    print(i,end=" ")
# Out:
# 33 11 88 44 99 22

# %%
# Inbuild function in tuple

# %%
a
# Out:
# (33, 11, 88, 44, 99, 22)

# %%
type(a)
# Out:
# tuple

# %%
b=(11,22,33,44,55,66)

# %%
b
# Out:
# (11, 22, 33, 44, 55, 66)

# %%
# Type,id,len,max,sum,sorted,sorted(a,reverce = True)

# %%
type(b)
# Out:
# tuple

# %%
id(b)
# Out:
# 2609190814912

# %%
len(b)
# Out:
# 6

# %%
min(b)
# Out:
# 11

# %%
max(b)
# Out:
# 66

# %%
sum(b)
# Out:
# 231

# %%
sorted(b)
# Out:
# [11, 22, 33, 44, 55, 66]

# %%
sorted(b,reverse=True)
# Out:
# [66, 55, 44, 33, 22, 11]

# %%
# Methods in Tuple

# %%
a=(33,11,99,44,66)

# %%
a.count(99)
# Out:
# 1

# %%
a.index(44)
# Out:
# 3

# %%
# unpacking of tuple

# %%
a=(44,77,88)

# %%
x,y,z=a

# %%
x
# Out:
# 44

# %%
y
# Out:
# 77

# %%
z
# Out:
# 88

# %%
a,b=88,99 #Multiple variable on a single line

# %%
# Tuple in tuple

# %%
a=(11,22,(33,44),99)

# %%
(a[2][0])
# Out:
# 33

# %%
a=[]

# %%
a.append((55,77))

# %%
a
# Out:
# [(55, 77)]

# %%
# X=[('Harsh',11,56,67),('Ritu',12,88,90)]

# %%
list1=[]
num=int(input('Enter the no of students '))
for i in range(num):
    name=input('Enter the name = ')
    roll=(int(input('Enter the number = ')))
    marks=float(input('Enter the marks = '))
    list1.append((name,roll,marks))
print(list1)
# Out:
# Enter the no of students  1
# Enter the name =  Harsh
# Enter the number =  1
# Enter the marks =  73.83
# [('Harsh', 1, 73.83)]
