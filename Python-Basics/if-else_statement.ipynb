# %% [markdown]
# # if-else Statment

# %% [markdown]
# Sometimes the programmer needs to check the evaluation of creatin
# expression(s),whether the expression(s) evaluate to True or False
# expression evaluates to False, then the program execution follows a
# different path than it would have if the expression had evaluated to true

# %% [markdown]
# Based on this, the conditional statements are further classified into following types:

# %% [markdown]
# - if
# - if-else
# - if-else-elif
# - nested if-else-elif

# %% [markdown]
# # An if...else statement evaluates like this:

# %% [markdown]
# if the expression evalutes True:

# %% [markdown]
# Execute the block of code inside if statement. After execution return to the code
# out of the if....else block \

# %% [markdown]
# if the expression evalutes False:

# %% [markdown]
# Execute the block of code inside else statement. After execution return to the code
# out of the if....else block \

# %%
a = int(input("Enter your age : "))
print("Your age is : ",a)

if(a>18):
  print("You can drive")
else:
  print("You can drive")
# Out:
# Enter your age :  18
# Your age is :  18
# You can drive

# %%
applePrice = 210
budget = 200
if (applePrice <= budget):
    print("Ramu, add 1kg Apple to the cart.")
else:
    print("Ramu, do not add Apples to the card.")
# Out:
# Ramu, do not add Apples to the card.

# %%
# !git add .
# !git commit -m "Day 8 Python Practice"
# !git push
# Out:
# ...
# [main 144f231] Day 8 Python Practice
#  2 files changed, 233 insertions(+), 1 deletion(-)
#  create mode 100644 Python-Basics/if-else_statement.ipynb
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    e2688c3..144f231  main -> main

# %%
a = int(input("Enter your age : "))
print("Your age is : ",a)

if(a>18):
  print("You can drive")
  print("Congratulations")
else:
  print("You can'not drive")
  print("Better luck next time")
# Out:
# Enter your age :  10
# Your age is :  10
# You can'not drive
# Better luck next time

# %%
# !git add .
# !git commit -m "Day 9 Python Practice"
# !git push
# Out:
# ...
# [main 1d21872] Day 9 Python Practice
#  1 file changed, 50 insertions(+), 13 deletions(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    144f231..1d21872  main -> main

# %%
marks = 35

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
# !git add .
# !git commit -m "Day 9 Python Practice"
# !git push
# Out:
# ...
# [main e070ca0] Day 9 Python Practice
#  1 file changed, 54 insertions(+), 10 deletions(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    1d21872..e070ca0  main -> main

# %%
marks = 82

if marks >= 90:
    print("Grade A+")
elif marks >= 80:
    print("Grade A")
elif marks >= 70:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 40:
    print("Grade D")
else:
    print("Fail")
# Out:
# Grade A

# %%
# !git add .
# !git commit -m "Day 10 Python Practice"
# !git push
# Out:
# ...
# [main 3babb8f] Day 10 Python Practice
#  1 file changed, 60 insertions(+), 1 deletion(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    e070ca0..3babb8f  main -> main

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number:  45
# Odd Number

# %%
# !git add .
# !git commit -m "Day 11 Python Practice"
# !git push
# Out:
# ...
# [main 4681781] Day 11 Python Practice
#  1 file changed, 83 insertions(+), 1 deletion(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    3babb8f..4681781  main -> main

# %%
marks = int(input("Enter your marks: "))

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  34
# Fail

# %%
# !git add .
# !git commit -m "Day 12 Python Practice"
# !git push
# Out:
# ...
# [main e73dfa6] Day 12 Python Practice
#  1 file changed, 54 insertions(+), 3 deletions(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    4681781..e73dfa6  main -> main

# %%
marks = int(input("Enter Your Marathi Marks : "))
marks = int(input("Enter Your English Marks : "))
marks = int(input("Enter Your Science Marks : "))
marks = int(input("Enter Your Maths Marks : "))

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Your Marathi Marks :  45
# Enter Your English Marks :  45
# Enter Your Science Marks :  45
# Enter Your Maths Marks :  33
# Fail

# %%
# !git add .
# !git commit -m "Day 15 Python Practice"
# !git push
# Out:
# ...
# [main 03af4d5] Day 15 Python Practice
#  2 files changed, 48 insertions(+), 2 deletions(-)
# To https://github.com/harshnimbhekar13/Python-Practice.git
#    61e44ab..03af4d5  main -> main
